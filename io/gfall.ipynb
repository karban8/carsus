# %% [markdown]
# # GFALL

# %% [markdown]
# Import the `GFALLReader` class.

# %%
from carsus.io.kurucz import GFALLReader
# Out:
#  ChiantiPy version 0.8.4
#  found PyQt5 widgets
#  using PyQt5 widgets

# %% [markdown]
# By default, `gfall.dat` is read directly from Harvard's server.

# %%
gfall_reader = GFALLReader()
# Out:
# [    carsus.io.kurucz.gfall][WARNING] - A specific combination to identify unique levels from GFALL data has not been given. Defaulting to ["energy", "j"]. (gfall.py:86)

# %%
gfall_reader.gfall
# Out:
# [    carsus.io.kurucz.gfall][INFO] - Parsing GFALL: http://kurucz.harvard.edu/linelists/gfall/gfall.dat (gfall.py:139)
#         wavelength  loggf  blank1  blank2  log_gamma_rad  log_gamma_stark  \
# 0           2.4898 -0.842     NaN     NaN          11.73             0.00
# 1           2.8787 -0.171     NaN     NaN          12.26             0.00
# 2           5.2682 -0.870     NaN     NaN           0.00             0.00
# 3           6.0313 -0.215     NaN     NaN           0.00             0.00
# 4           6.1092 -5.150     NaN     NaN           0.00             0.00
# ...            ...    ...     ...     ...            ...              ...
# 564920  99694.5982 -1.886     NaN     NaN           8.23            -5.18
# 564921  99713.4910 -4.028     NaN     NaN           8.73            -5.55
# 564922  99753.2890  0.529     NaN     NaN           6.97            -2.60
# 564924  99768.2213 -3.114     NaN     NaN           8.33            -4.99
# 564925  99962.7500 -2.878     NaN     NaN           7.67            -1.54
#
#         log_gamma_vderwaals  ref  isotope  log_f_hyperfine  ...  \
# 0                      0.00  NBS      0.0              0.0  ...
# 1                      0.00  NBS      0.0              0.0  ...
# 2                      0.00  NBS      0.0              0.0  ...
# 3                      0.00  NBS      0.0              0.0  ...
# 4                      0.00  DRA      0.0              0.0  ...
# ...                     ...  ...      ...              ...  ...
# 564920                -7.48  K94      0.0              0.0  ...
# 564921                -7.52  K88      0.0              0.0  ...
# 564922                -6.58  K88      0.0              0.0  ...
# 564924                -7.49    K      0.0              0.0  ...
# 564925                -6.46  K88      0.0              0.0  ...
#
#         hyperfine_f_lower  hyperfine_f_upper hyperfine_note_lower  \
# 0                     NaN                NaN                  NaN
# 1                     NaN                NaN                  NaN
# 2                     NaN                NaN                  NaN
# 3                     NaN                NaN                  NaN
# 4                     NaN                NaN                  NaN
# ...                   ...                ...                  ...
# 564920                NaN                NaN                  NaN
# 564921                NaN                NaN                  NaN
# 564922                NaN                NaN                  NaN
# 564924                NaN                NaN                  NaN
# 564925                NaN                NaN                  NaN
#
#        hyperfine_note_upper  lande_g_lower lande_g_upper  \
# 0                       NaN            0.0           0.0
# 1                       NaN            0.0           0.0
# 2                       NaN            0.0           0.0
# 3                       NaN            0.0           0.0
# 4                       NaN            0.0           0.0
# ...                     ...            ...           ...
# 564920                  NaN         1491.0        1355.0
# 564921                  NaN         1302.0         814.0
# 564922                  NaN         1000.0           0.0
# 564924                  NaN            1.0         489.0
# 564925                  NaN         1501.0        1000.0
#
#         energy_lower_predicted  energy_upper_predicted  atomic_number  \
# 0                        False                   False              7
# 1                        False                   False              7
# 2                        False                   False              5
# 3                        False                   False              5
# 4                        False                   False              5
# ...                        ...                     ...            ...
# 564920                   False                   False             26
# 564921                   False                   False             26
# 564922                   False                   False             20
# 564924                   False                   False             22
# 564925                   False                   False             20
#
#         ion_charge
# 0                5
# 1                5
# 2                3
# 3                3
# 4                3
# ...            ...
# 564920           0
# 564921           1
# 564922           0
# 564924           0
# 564925           0
#
# [563283 rows x 37 columns]

# %% [markdown]
# A raw version of the file is stored inside the `gfall_raw` attribute.

# %%
gfall_reader.gfall_raw
# Out:
#          wavelength  loggf  element_code     e_first  j_first  blank1  \
# 0            2.4898 -0.842          7.05       0.000      0.0     NaN
# 1            2.8787 -0.171          7.05       0.000      0.0     NaN
# 2            5.2682 -0.870          5.03       0.000      0.0     NaN
# 3            6.0313 -0.215          5.03       0.000      0.0     NaN
# 4            6.1092 -5.150          5.03       0.000      0.0     NaN
# ...             ...    ...           ...         ...      ...     ...
# 564981  452493.3210  3.578          1.00  109430.063      5.5     NaN
# 564982  518497.2090  3.637          1.00  109452.156      6.5     NaN
# 564983  591062.8690  3.694          1.00  109471.438      7.5     NaN
# 564984  669623.8150  3.748          1.00  109488.352      8.5     NaN
# 564985  754956.4080  3.800          1.00  109503.281      9.5     NaN
#
#        label_first     e_second  j_second  blank2  ... hyperfine_f_first  \
# 0           1s2 1S  4016390.000       1.0     NaN  ...               NaN
# 1           1s2 1S  3473790.000       1.0     NaN  ...               NaN
# 2           1s2 1S  1898180.000       1.0     NaN  ...               NaN
# 3           1s2 1S  1658020.000       1.0     NaN  ...               NaN
# 4           1s2 1S  1636882.000       1.0     NaN  ...               NaN
# ...            ...          ...       ...     ...  ...               ...
# 564981     AVERAGE   109452.156       6.5     NaN  ...               NaN
# 564982     AVERAGE   109471.438       7.5     NaN  ...               NaN
# 564983     AVERAGE   109488.352       8.5     NaN  ...               NaN
# 564984     AVERAGE   109503.281       9.5     NaN  ...               NaN
# 564985     AVERAGE   109516.523      10.5     NaN  ...               NaN
#
#         hyperfine_note_first  blank4  hyperfine_f_second  \
# 0                        NaN     NaN                 NaN
# 1                        NaN     NaN                 NaN
# 2                        NaN     NaN                 NaN
# 3                        NaN     NaN                 NaN
# 4                        NaN     NaN                 NaN
# ...                      ...     ...                 ...
# 564981                   NaN     NaN                 NaN
# 564982                   NaN     NaN                 NaN
# 564983                   NaN     NaN                 NaN
# 564984                   NaN     NaN                 NaN
# 564985                   NaN     NaN                 NaN
#
#        hyperfine_note_second  line_strength_class  line_code  lande_g_first  \
# 0                        NaN                  NaN        NaN            0.0
# 1                        NaN                  NaN        NaN            0.0
# 2                        NaN                  NaN        NaN            0.0
# 3                        NaN                  NaN        NaN            0.0
# 4                        NaN                  NaN        NaN            0.0
# ...                      ...                  ...        ...            ...
# 564981                   NaN                  NaN        NaN            0.0
# 564982                   NaN                  NaN        NaN            0.0
# 564983                   NaN                  NaN        NaN            0.0
# 564984                   NaN                  NaN        NaN            0.0
# 564985                   NaN                  NaN        NaN            0.0
#
#         lande_g_second  isotopic_shift
# 0                  0.0             NaN
# 1                  0.0             NaN
# 2                  0.0             NaN
# 3                  0.0             NaN
# 4                  0.0             NaN
# ...                ...             ...
# 564981             0.0             NaN
# 564982             0.0             NaN
# 564983             0.0             NaN
# 564984             0.0             NaN
# 564985             0.0             NaN
#
# [564986 rows x 34 columns]

# %% [markdown]
# Dump data with method `to_hdf`.

# %%
gfall_reader.to_hdf('gfall.h5')
# Out:
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3343: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['label_first', 'label_second', 'ref', 'blank3', 'hyperfine_note_first',
#        'blank4', 'line_code'],
#       dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  (warnings.py:99)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3343: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['ref', 'blank3', 'blank4', 'line_code', 'label_lower', 'label_upper',
#        'hyperfine_note_lower', 'hyperfine_note_upper'],
#       dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  (warnings.py:99)

# %%
# Hidden cell
# !rm gfall.h5
