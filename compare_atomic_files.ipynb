# %% [markdown]
# # Compare atomic files
#
# This notebook shows how to compare the tables `levels_prepared` and `lines_prepared` of the atomic files generated by Carsus.
#
# ## Create sample files
#
# Let's create two different TARDIS atomic files.

# %%
from carsus.io.nist import NISTWeightsComp, NISTIonizationEnergies
from carsus.io.kurucz import GFALLReader
from carsus.io.zeta import KnoxLongZeta
from carsus.io.chianti_ import ChiantiReader
from carsus.io.output import TARDISAtomData
# Out:
#  ChiantiPy version 0.8.4
#  found PyQt5 widgets
#  using PyQt5 widgets

# %% [markdown]
# For the first atomic file we grab species `H-C` from GFALL and replace `H-He` from Chianti.

# %%
atomic_weights = NISTWeightsComp()
ionization_energies = NISTIonizationEnergies('H-C')
gfall_reader = GFALLReader(ions='H-C')
chianti_reader = ChiantiReader(ions='H-He', collisions=True, priority=20)
zeta_data = KnoxLongZeta()
# Out:
# [carsus.io.nist.weightscomp][INFO] - Downloading data from the NIST Atomic Weights and Isotopic Compositions Database. (weightscomp.py:49)
# [ carsus.io.nist.ionization][INFO] - Downloading ionization energies from the NIST Atomic Spectra Database. (ionization.py:65)
# [    carsus.io.kurucz.gfall][WARNING] - A specific combination to identify unique levels from GFALL data has not been given. Defaulting to ["energy", "j"]. (gfall.py:86)

# %%
atom_data_a = TARDISAtomData(atomic_weights,
                             ionization_energies,
                             gfall_reader,
                             zeta_data,
                             chianti_reader)
# Out:
# [    carsus.io.kurucz.gfall][INFO] - Parsing GFALL: http://kurucz.harvard.edu/linelists/gfall/gfall.dat (gfall.py:139)
# [     carsus.io.output.base][INFO] - Ingesting levels from Chianti. (base.py:255)
# [     carsus.io.output.base][INFO] - Ingesting lines from GFALL. (base.py:327)
# [    carsus.io.kurucz.gfall][INFO] - Extracting line data: atomic_number, ion_charge, energy_lower, j_lower, energy_upper, j_upper, wavelength, loggf. (gfall.py:343)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/carsus-0.1.dev637-py3.6.egg/carsus/io/output/base.py:121: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ['atomic_number', 'ion_number']).loc[ion]
#  (warnings.py:99)
# [     carsus.io.output.base][INFO] - Ingesting lines from Chianti. (base.py:352)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/carsus-0.1.dev637-py3.6.egg/carsus/io/output/base.py:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['line_id'] = range(start, len(df) + start)
#  (warnings.py:99)
# [     carsus.io.output.base][INFO] - Ingesting collisions from Chianti (base.py:499)

# %%
atom_data_a.to_hdf('A.h5')
# Out:
# [     carsus.io.output.base][INFO] - Signing TARDISAtomData. (base.py:840)
# [     carsus.io.output.base][INFO] - MD5: 5c54bf15cb33253f18c4b0ba6c092182 (base.py:841)
# [     carsus.io.output.base][INFO] - UUID1: 4ee1a9c8ebb711eaa134000d3a8f33ce (base.py:842)

# %% [markdown]
# For the first atomic file we grab species `H-C` from GFALL and replace `C` from Chianti.

# %%
chianti_reader = ChiantiReader(ions='C', collisions=True, priority=20)

# %%
atom_data_b = TARDISAtomData(atomic_weights,
                             ionization_energies,
                             gfall_reader,
                             zeta_data,
                             chianti_reader)
# Out:
# [     carsus.io.output.base][INFO] - Ingesting levels from Chianti. (base.py:255)
# [     carsus.io.output.base][INFO] - Ingesting lines from GFALL. (base.py:327)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/carsus-0.1.dev637-py3.6.egg/carsus/io/output/base.py:121: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ['atomic_number', 'ion_number']).loc[ion]
#  (warnings.py:99)
# [     carsus.io.output.base][INFO] - Ingesting lines from Chianti. (base.py:352)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/carsus-0.1.dev637-py3.6.egg/carsus/io/output/base.py:356: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['line_id'] = range(start, len(df) + start)
#  (warnings.py:99)
# [     carsus.io.output.base][INFO] - Ingesting collisions from Chianti (base.py:499)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/carsus-0.1.dev637-py3.6.egg/carsus/io/output/base.py:224: RuntimeWarning: divide by zero encountered in true_divide
#   x = (kt / delta_e) / (kt / delta_e + c)
#  (warnings.py:99)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/carsus-0.1.dev637-py3.6.egg/carsus/io/output/base.py:224: RuntimeWarning: invalid value encountered in true_divide
#   x = (kt / delta_e) / (kt / delta_e + c)
#  (warnings.py:99)

# %%
atom_data_b.to_hdf('B.h5')
# Out:
# [     carsus.io.output.base][INFO] - Signing TARDISAtomData. (base.py:840)
# [     carsus.io.output.base][INFO] - MD5: 9e52816947227e29d7b653c9d47e2260 (base.py:841)
# [     carsus.io.output.base][INFO] - UUID1: 6da277fcebb711eaa134000d3a8f33ce (base.py:842)

# %% [markdown]
# ## Energy levels and transition lines
#
# Define the following functions to compare both dataframes.

# %%
import pandas as pd
from carsus.util import parse_selected_species

# %%
def highlight_values(val):
    if val == True:
        return 'background-color: #BCF5A9'
    else:
        return 'background-color: #F5A9A9'
    
def highlight_diff(val):
    if val == 0:
        return 'background-color: #BCF5A9'
    else:
        return 'background-color: #F5A9A9'

# %%
def compare_levels_lines(path_a, path_b, ions='H-Zn'):
    
    # Read data
    levels_a = pd.read_hdf(path_a, key='levels')
    levels_b = pd.read_hdf(path_b, key='levels')
    lines_a = pd.read_hdf(path_a, key='lines')
    lines_b = pd.read_hdf(path_b, key='lines')
    
    # Get ions list
    ions = parse_selected_species(ions)
    
    lvl_eq = []
    lns_eq = []
    for ion in ions:
        
        # How many levels per ion in A
        try:
            num_lvl_a = len(levels_a.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lvl_a = 0
            
        # How many levels per ion in B
        try:
            num_lvl_b = len(levels_b.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lvl_b = 0

        # If level number is the same in A and B (and not zero) 
        # then compare cell against cell. `True` means all cells 
        # are equal in both dataframes.
        if num_lvl_a == num_lvl_b:
            val_lvl = True
            
            if num_lvl_a != 0:
                try:
                    k = levels_a.loc[ion].eq(levels_b.loc[ion]).sum().sum()
                    if num_lvl_a*3 != k:  # x3 because this df has three columns!
                        val_lvl = False
                        
                except (KeyError, TypeError, ValueError):
                    pass

        else:
            val_lvl = False
            
        # Append the results
        lvl_eq.append((ion, num_lvl_a, num_lvl_b, val_lvl))
        
        
        # Same for lines
        try:
            num_lns_a = len(lines_a.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lns_a = 0
            
        try:
            num_lns_b = len(lines_b.loc[ion])
            
        except (KeyError, TypeError, ValueError):
            num_lns_b = 0

        if num_lns_a == num_lns_b:
            val_lns = True
            
            if num_lns_a != 0:
                try:
                    k = lines_a.loc[ion].eq(lines_b.loc[ion]).sum().sum()
                    if num_lns_a*8 != k:
                        val_lvl = False
            
                except (KeyError, TypeError, ValueError):
                    pass
            
        else:
            val_lns = False
        
        lns_eq.append((ion, num_lns_a, num_lns_b, val_lns))
            
    df_lvl = pd.DataFrame(lvl_eq, columns=['ion', 'num_lvl_a', 'num_lvl_b', 'val_lvl'])
    df_lns = pd.DataFrame(lns_eq, columns=['ion', 'num_lns_a', 'num_lns_b', 'val_lns'])
    df = pd.merge(df_lvl, df_lns).set_index('ion')
    
    df['diff_lvl'] = abs(df['num_lvl_b'] - df['num_lvl_a'])
    df['diff_lns'] = abs(df['num_lns_b'] - df['num_lns_a'])
    df = df[['num_lvl_a', 'num_lvl_b', 'diff_lvl', 'val_lvl', 
          'num_lns_a', 'num_lns_b', 'diff_lns', 'val_lns']]

    return df

# %% [markdown]
# Then, comparison is straightforward.

# %%
tt = compare_levels_lines('A.h5', 'B.h5', ions='H-C')
# Out:
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/ipykernel_launcher.py:54: PerformanceWarning: indexing past lexsort depth may impact performance.
#  (warnings.py:99)
# [               py.warnings][WARNING] - /usr/share/miniconda/envs/carsus/lib/python3.6/site-packages/ipykernel_launcher.py:70: PerformanceWarning: indexing past lexsort depth may impact performance.
#  (warnings.py:99)

# %% [markdown]
# - **num_xxx_x:** _(int)_ number of levels/lines.
# - **diff_xxx:** _(int)_ difference in number of levels/lines.
# - **val_xxx:** _(bool)_ _True_ if levels/lines have the same value.

# %%
tt.style.applymap(highlight_values, subset=['val_lvl', 'val_lns']).applymap(
                    highlight_diff, subset=['diff_lvl', 'diff_lns'])
# Out:
# <style  type="text/css" >
#     #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow0_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow0_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow0_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow0_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow1_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow1_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow1_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow1_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow2_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow2_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow2_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow2_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow3_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow3_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow3_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow3_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow4_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow4_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow4_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow4_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow5_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow5_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow5_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow5_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow6_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow6_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow6_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow6_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow7_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow7_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow7_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow7_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow8_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow8_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow8_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow8_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow9_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow9_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow9_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow9_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow10_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow10_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow10_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow10_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow11_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow11_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow11_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow11_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow12_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow12_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow12_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow12_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow13_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow13_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow13_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow13_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow14_col2 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow14_col3 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow14_col6 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow14_col7 {
#             background-color:  #BCF5A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow15_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow15_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow15_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow15_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow16_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow16_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow16_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow16_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow17_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow17_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow17_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow17_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow18_col2 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow18_col3 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow18_col6 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000d3a8f33cerow18_col7 {
#             background-color:  #F5A9A9;
#         }    #T_6ddb020c_ebb7_11ea_a134_000

# %%
# Hidden cell
# !rm A.h5 B.h5
